# %% [markdown]
# <a href="https://colab.research.google.com/github/alinastepd/application/blob/main/Twitter_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset 1 (Tweets.csv).

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.stem import PorterStemmer
import string
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
dataset1 = pd.read_csv('Tweets.csv')
dataset1.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# ...

# %%
X = dataset1['text']
Y = dataset1['airline_sentiment']

# %% [markdown]
# Cleaning the text data

# %%
stop_words = stopwords.words('english')
punct = string.punctuation
stemmer = PorterStemmer()

# %%
cleaned_data = []
for i in range(len(X)):
  dataset1 = re.sub('[a-zA-Z]', ' ', X.iloc[i])
  dataset1 = dataset1.lower().split()
  dataset1 = [stemmer.stem(word) for word in dataset1 if (word not in stop_words) and (word not in punct)]
  dataset1 = ' '.join(dataset1)
  cleaned_data.append(dataset1)

# %%
Y
# Out:
# 0         neutral
# 1        positive
# 2         neutral
# 3        negative
# 4        negative
#            ...
# 14635    positive
# 14636    negative
# 14637     neutral
# 14638    negative
# 14639     neutral
# Name: airline_sentiment, Length: 14640, dtype: object

# %%
sentiments = ['negative', 'neutral', 'positive'] #negative - 0, neutral - 1, positive - 2
Y = Y.apply(lambda X: sentiments.index(X))

# %%
Y.head()
# Out:
# 0    1
# 1    2
# 2    1
# 3    0
# 4    0
# Name: airline_sentiment, dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 3000, stop_words = ['virginamerica', 'unit'])
X_fin = cv.fit_transform(cleaned_data).toarray()

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
model = MultinomialNB()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_fin, Y, test_size = 0.3)

# %%
Y_pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report
cf = classification_report(Y_test, Y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.99      0.78      2726
#            1       0.82      0.07      0.14       916
#            2       0.75      0.07      0.12       750
#
#     accuracy                           0.64      4392
#    macro avg       0.73      0.38      0.34      4392
# weighted avg       0.69      0.64      0.53      4392

# %%
dataset2 = pd.read_csv('twitter_validation.csv')
dataset2.head()
# Out:
#    3364   Facebook Irrelevant  \
# 0   352     Amazon    Neutral
# 1  8312  Microsoft   Negative
# 2  4371      CS-GO   Negative
# 3  4433     Google    Neutral
# 4  6273       FIFA   Negative
#
#   I mentioned on Facebook that I was struggling for motivation to go for a run the other day, which has been translated by Tom’s great auntie as ‘Hayley can’t get out of bed’ and told to his grandma, who now thinks I’m a lazy, terrible person 🤣
# 0  BBC News - Amazon boss Jeff Bezos rejects clai...
# 1  @Microsoft Why do I pay for WORD when it funct...
# 2  CSGO matchmaking is so full of closet hacking,...
# 3  Now the President is slapping Americans in the...
# 4  Hi @EAHelp I’ve had Madeleine McCann in my cel...

# %%
X2 = dataset2['I mentioned on Facebook that I was struggling for motivation to go for a run the other day, which has been translated by Tom’s great auntie as ‘Hayley can’t get out of bed’ and told to his grandma, who now thinks I’m a lazy, terrible person 🤣']
Y2 = dataset2['Irrelevant']

# %%
cleaned_data2 = []
for i in range(len(X2)):
  dataset2 = re.sub('[a-zA-Z]', ' ', X2.iloc[i])
  dataset2 = dataset2.lower().split()
  dataset2 = [stemmer.stem(word) for word in dataset2 if (word not in stop_words) and (word not in punct)]
  dataset2 = ' '.join(dataset2)
  cleaned_data2.append(dataset2)

# %%
#cleaned_data2

# %%
Y2
# Out:
# 0         Neutral
# 1        Negative
# 2        Negative
# 3         Neutral
# 4        Negative
#           ...
# 994    Irrelevant
# 995    Irrelevant
# 996      Positive
# 997      Positive
# 998       Neutral
# Name: Irrelevant, Length: 999, dtype: object

# %%
sentiments2 = ['Negative', 'Neutral','Positive', 'Irrelevant'] #negative - 0, neutral - 1, positive - 2, Irrelevant - 3
Y2 = Y2.apply(lambda X2: sentiments2.index(X2))

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 3000)
X2_fin = cv.fit_transform(cleaned_data2).toarray()

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
model2= MultinomialNB()

# %%
X2_train, X2_test, Y2_train, Y2_test = train_test_split(X2_fin, Y2, test_size = 0.3)

# %%
model2.fit(X2_train, Y2_train)
# Out:
# MultinomialNB()

# %%
Y2_pred = model2.predict(X2_test)

# %%
from sklearn.metrics import classification_report
cf2 = classification_report(Y2_test, Y2_pred)
print(cf2)
# Out:
#               precision    recall  f1-score   support
#
#   Irrelevant       0.33      0.02      0.04        54
#     Negative       0.17      0.08      0.11        78
#      Neutral       0.26      0.80      0.40        82
#     Positive       0.00      0.00      0.00        86
#
#     accuracy                           0.24       300
#    macro avg       0.19      0.23      0.13       300
# weighted avg       0.18      0.24      0.14       300
